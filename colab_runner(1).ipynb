# %% [markdown]
# # Colab Runner for MLDL23-Ego

# %% [markdown]
# <a href="https://colab.research.google.com/github/EgovisionPolito/mldl23-ego/blob/master/colab_runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EPIC-Kitchens-55 dataset
#
# **READ carefully!**
#
# To develop the project, you need to download the RGB frames for a subset of EPIC-Kitchens-55 (participants P08, P01 and P22) from [here](https://politoit-my.sharepoint.com/:f:/g/personal/simone_peirone_polito_it/EqCmaEAi2oBEqEqzBZ-pIA0Bke4EGNkUEhqwApEhUp9tDw?e=DtSbMP) (you need to login with your Polito credentials).
#
# You also need to the pretrained checkpoints for each domain from [here](https://politoit-my.sharepoint.com/:f:/g/personal/simone_peirone_polito_it/ErdsZhvmR65Lun5_5O0-l5sBTPjCCZZq2f700Tj_CNzjTQ?e=L1yflf).
#
# Upload the dataset on your Google Drive to access it from Google Colab.
#
# **NOTE**: As the dataset is quite heavy, we stronly suggest you to implement and test all your code on one for the three dataset. Then, once you are sure everything works, repeat the experiments on the remaining two datasets.

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/train*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/safn*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/hafn*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/grd*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gtd*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gsd*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/Source*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/allgd*
# rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/att*
# Out:
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/train*': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/safn*': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/hafn*': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gtd*': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gsd*': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/Source*': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/allgd*': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/att*': No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-3-d7c1afa45b49> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/train*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/safn*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/hafn*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/grd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gtd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gsd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/Source*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/allgd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/att*\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'rm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/train*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/safn*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/hafn*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/grd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gtd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/gsd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/Source*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/allgd*\nrm -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/models/att*\n'' returned non-zero exit status 1.

# %%
# %%bash
#
# # As read and write operations from google drive are slow, we suggest to copy and unzip
# # the dataset in a local directory on the Colab's machine.
# mkdir -p ek_data/frames
#
# # Copy the *.tar.gz files of Epic-Kitchens
# # TODO: replace with your path
# cp /content/drive/MyDrive/MLDL23/Epic-Kitchens-55/data_P08/*.tar.gz ./ek_data
# # Untar
# for file in ./ek_data/*.tar.gz; do
#   fn=$(basename $file)
#   fn=${fn/.tar.gz/}
#   ls -lah $file
#   mkdir -p ek_data/frames/$fn
#   tar xf $file --directory=ek_data/frames/$fn
# done
# Out:
# -rw------- 1 root root 1.1G Aug 25 10:32 ./ek_data/P01_01.tar.gz
# -rw------- 1 root root 390M Aug 25 10:32 ./ek_data/P01_02.tar.gz
# -rw------- 1 root root 44M Aug 25 10:32 ./ek_data/P01_03.tar.gz
# -rw------- 1 root root 45M Aug 25 10:32 ./ek_data/P01_04.tar.gz
# -rw------- 1 root root 420M Aug 25 10:33 ./ek_data/P01_05.tar.gz
# -rw------- 1 root root 361M Aug 25 10:33 ./ek_data/P01_06.tar.gz
# -rw------- 1 root root 87M Aug 25 10:33 ./ek_data/P01_07.tar.gz
# -rw------- 1 root root 57M Aug 25 10:33 ./ek_data/P01_08.tar.gz
# -rw------- 1 root root 1.7G Aug 25 10:34 ./ek_data/P01_09.tar.gz
# -rw------- 1 root root 90M Aug 25 10:34 ./ek_data/P01_10.tar.gz
# -rw------- 1 root root 355M Aug 25 10:34 ./ek_data/P01_11.tar.gz
# -rw------- 1 root root 88M Aug 25 10:34 ./ek_data/P01_12.tar.gz
# -rw------- 1 root root 42M Aug 25 10:34 ./ek_data/P01_13.tar.gz
# -rw------- 1 root root 825M Aug 25 10:35 ./ek_data/P01_14.tar.gz
# -rw------- 1 root root 728M Aug 25 10:35 ./ek_data/P01_15.tar.gz
# -rw------- 1 root root 92M Aug 25 10:35 ./ek_data/P01_16.tar.gz
# -rw------- 1 root root 739M Aug 25 10:35 ./ek_data/P01_17.tar.gz
# -rw------- 1 root root 1.9G Aug 25 10:36 ./ek_data/P01_18.tar.gz
# -rw------- 1 root root 375M Aug 25 10:36 ./ek_data/P01_19.tar.gz
# -rw------- 1 root root 436M Aug 25 15:29 ./ek_data/P08_01.tar.gz
# -rw------- 1 root root 65M Aug 25 15:29 ./ek_data/P08_02.tar.gz
# -rw------- 1 root root 78M Aug 25 15:29 ./ek_data/P08_03.tar.gz
# -rw------- 1 root root 168M Aug 25 15:29 ./ek_data/P08_04.tar.gz
# -rw------- 1 root root 1.4G Aug 25 15:30 ./ek_data/P08_05.tar.gz
# -rw------- 1 root root 372M Aug 25 15:30 ./ek_data/P08_06.tar.gz
# -rw------- 1 root root 20M Aug 25 15:30 ./ek_data/P08_07.tar.gz
# -rw------- 1 root root 85M Aug 25 15:30 ./ek_data/P08_08.tar.gz
# -rw------- 1 root root 397M Aug 25 15:30 ./ek_data/P08_09.tar.gz
# -rw------- 1 root root 202M Aug 25 15:31 ./ek_data/P08_10.tar.gz
# -rw------- 1 root root 59M Aug 25 15:31 ./ek_data/P08_11.tar.gz
# -rw------- 1 root root 9.0M Aug 25 15:31 ./ek_data/P08_12.tar.gz
# -rw------- 1 root root 12M Aug 25 15:31 ./ek_data/P08_13.tar.gz
# -rw------- 1 root root 86M Aug 25 15:31 ./ek_data/P08_14.tar.gz
# -rw------- 1 root root 347M Aug 25 15:31 ./ek_data/P08_15.tar.gz
# -rw------- 1 root root 285M Aug 25 15:31 ./ek_data/P08_16.tar.gz
# -rw------- 1 root root 477M Aug 25 15:31 ./ek_data/P08_17.tar.gz
# -rw------- 1 root root 379M Aug 25 15:31 ./ek_data/P08_18.tar.gz
# -rw------- 1 root root 52M Aug 25 15:32 ./ek_data/P08_19.tar.gz
# -rw------- 1 root root 69M Aug 25 15:32 ./ek_data/P08_20.tar.gz
# -rw------- 1 root root 1.1G Aug 25 15:32 ./ek_data/P08_21.tar.gz
# -rw------- 1 root root 91M Aug 25 15:32 ./ek_data/P08_22.tar.gz
# -rw------- 1 root root 1.4G Aug 25 15:33 ./ek_data/P08_23.tar.gz
# -rw------- 1 root root 558M Aug 25 15:33 ./ek_data/P08_24.tar.gz
# -rw------- 1 root root 18M Aug 25 15:33 ./ek_data/P08_25.tar.gz
# -rw------- 1 root root 311M Aug 25 15:33 ./ek_data/P08_26.tar.gz
# -rw------- 1 root root 118M Aug 25 15:33 ./ek_data/P08_27.tar.gz
# -rw------- 1 root root 24M Aug 25 15:33 ./ek_data/P08_28.tar.gz

# %% [markdown]
# ## Running the code

# %%
# Install conda on Google Colab

# !pip install -q condacolab
import condacolab
condacolab.install()


#!conda clean --all
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# Create a conda environment

# !conda env create --name egovision -f drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/requirements.yaml
# Out:
# - WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.7.3
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.3
#
#
#
# Downloading and Extracting Packages
# munkres-1.1.4        | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
# defusedxml-0.7.1     | 23 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# lcms2-2.12           | 312 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ply-3.11             | 82 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libxcb-1.15          | 505 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# cffi-1.15.1          | 227 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# jupyter_console-6.4. | 23 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# zlib-1.2.12          | 103 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libxml2-2.9.14       | 718 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# pkgutil-resolve-name | 9 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# jupyter_client-7.3.5 | 191 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.3          | 70 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.5.13      | 91 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# six-1.16.0           | 18 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  8.29it/s]
#
#
#
# libxcb-1.15          | 505 KB    | :   3% 0.03165825164677399/1 [00:00<00:04,  4.69s/it]
#
# lcms2-2.12           | 312 KB    | :   5% 0.0513564767651438/1 [00:00<00:03,  3.18s/it]
#
#
# ply-3.11             | 82 KB     | :  20% 0.19607233039336533/1 [00:00<00:00,  1.13it/s]
#
#
#
#
# cffi-1.15.1          | 227 KB    | :   7% 0.07041823722315584/1 [00:00<00:02,  2.66s/it]
# defusedxml-0.7.1     | 23 KB     | :  69% 0.6876521447158567/1 [00:00<00:00,  3.46it/s]
#
#
#
#
#
#
#
#
# pkgutil-resolve-name | 9 KB      | : 100% 1.0/1 [00:00<00:00,  4.51it/s]
#
#
#
#
#
#
#
# libxml2-2.9.14       | 718 KB    | :   2% 0.022280425482148734/1 [00:00<00:09, 10.05s/it]
#
#
# ply-3.11             | 82 KB     | : 100% 1.0/1 [00:00<00:00,  1.13it/s]
#
#
#
#
#
# jupyter_console-6.4. | 23 KB     | :  69% 0.6926231240752484/1 [00:00<00:00,  2.76it/s]
#
#
#
#
#
#
# zlib-1.2.12          | 103 KB    | :  16% 0.1550604758569779/1 [00:00<00:01,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | :   1% 0.012539482455515987/1 [00:00<00:20, 20.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.3          | 70 KB     | :  23% 0.2276693902506809/1 [00:00<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
# jupyter_client-7.3.5 | 191 KB    | :   8% 0.08368192288637258/1 [00:00<00:03,  3.33s/it]
#
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00,  3.83it/s]
#
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00,  3.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.5.13      | 91 KB     | :  18% 0.17652319129451058/1 [00:00<00:01,  1.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :   0% 0.00034667229614176206/1 [00:00<14:38, 878.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.3 MB    | :   1% 0.0121654121827871/1 [00:00<00:26, 26.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     | :  87% 0.8690855081688945/1 [00:00<00:00,  2.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | :   1% 0.005163439044536868/1 [00:00<01:03, 63.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# six-1.16.0           | 18 KB     | :  87% 0.8671535937334603/1 [00:00<00:00,  2.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# defusedxml-0.7.1     | 23 KB     | : 100% 1.0/1 [00:00<00:00,  3.46it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :   4% 0.03640059109488501/1 [00:00<00:08,  8.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | :  73% 0.7332083443242352/1 [00:00<00:00,  2.22it/s]
#
#
#
#
#
#
#
#
# pkgutil-resolve-name | 9 KB      | : 100% 1.0/1 [00:00<00:00,  4.51it/s]
#
#
#
# libxcb-1.15          | 505 KB    | : 100% 1.0/1 [00:00<00:00,  2.27it/s]
#
#
#
# libxcb-1.15          | 505 KB    | : 100% 1.0/1 [00:00<00:00,  2.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :   9% 0.09117481388528342/1 [00:00<00:03,  4.00s/it]
#
#
#
#
# cffi-1.15.1          | 227 KB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
#
#
#
#
# cffi-1.15.1          | 227 KB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  14% 0.13762890156827953/1 [00:00<00:02,  3.20s/it]
#
#
#
#
#
# jupyter_console-6.4. | 23 KB     | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
#
#
#
#
#
# jupyter_console-6.4. | 23 KB     | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
#
#
#
#
#
#
#
# libxml2-2.9.14       | 718 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
#
#
#
#
#
#
#
# libxml2-2.9.14       | 718 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  18% 0.17749621562458218/1 [00:00<00:02,  3.14s/it]
#
#
#
#
#
#
# zlib-1.2.12          | 103 KB    | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
#
#
#
#
#
#
# zlib-1.2.12          | 103 KB    | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  21% 0.21493682360789249/1 [00:00<00:02,  3.00s/it]
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.3          | 70 KB     | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.3          | 70 KB     | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  26% 0.2551508099603369/1 [00:00<00:02,  2.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  29% 0.2932847625359307/1 [00:01<00:01,  2.79s/it]
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.01it/s]
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  34% 0.34389891777262793/1 [00:01<00:01,  2.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  39% 0.38584626560578117/1 [00:01<00:01,  2.57s/it]
#
#
#
#
#
#
#
#
#
# jupyter_client-7.3.5 | 191 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
# jupyter_client-7.3.5 | 191 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.5.13      | 91 KB     | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.5.13      | 91 KB     | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  43% 0.42606025195822556/1 [00:01<00:01,  2.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  49% 0.48638123148689216/1 [00:01<00:01,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  56% 0.5571023798998116/1 [00:01<00:00,  1.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# six-1.16.0           | 18 KB     | : 100% 1.0/1 [00:01<00:00,  2.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     | : 100% 1.0/1 [00:01<00:00,  2.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  63% 0.625050149943597/1 [00:01<00:00,  1.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  68% 0.6787843558455701/1 [00:01<00:00,  2.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  73% 0.7280118218977003/1 [00:01<00:00,  2.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  77% 0.7734258926922711/1 [00:02<00:00,  2.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  82% 0.8157199128215661/1 [00:02<00:00,  2.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  85% 0.8545472099894434/1 [00:02<00:00,  2.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  89% 0.8892144396036197/1 [00:02<00:00,  3.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  92% 0.9235349969216541/1 [00:02<00:00,  3.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  96% 0.9564688650551215/1 [00:02<00:00,  3.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | :  99% 0.9914827669654395/1 [00:02<00:00,  3.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.0 MB    | : 100% 1.0/1 [00:04<00:00,  2.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.2       | 45.1 MB   | : 100% 1.0/1 [00:44<00:00,  3.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# / By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# - Enabling nb_conda_kernels...
# CONDA_PREFIX: /usr/local/envs/egovision
# Status: enabled
#
# / Config option `kernel_spec_manager_class` not recognized by `EnableNBExtensionApp`.
# Enabling notebook extension nb_conda/main...
# Paths used for configuration of notebook:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/notebook.json
# Enabling tree extension nb_conda/tree...
# Paths used for configuration of tree:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/tree.json
# Paths used for configuration of tree:
#
#       - Validating: OK
# Paths used for configuration of tree:
#     	/usr/local/envs/egovision/etc/jupyter/nbconfig/tree.json
# Config option `kernel_spec_manager_class` not recognized by `EnableServerExtensionApp`.
# Enabling: nb_conda
# - Writing config: /usr/local/envs/egovision/etc/jupyter
#     - Validating...
#       nb_conda 2.2.1 OK
#
# /
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# / Ran pip subprocess with arguments:
# ['/usr/local/envs/egovision/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting antlr4-python3-runtime==4.9.3
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: click==8.1.3 in /usr/local/envs/egovision/lib/python3.7/site-packages (from -r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 2)) (8.1.3)
# Collecting docker-pycreds==0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting einops==0.5.0
#   Downloading einops-0.5.0-py3-none-any.whl (36 kB)
# Collecting filelock==3.8.0
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting gdown==4.5.3
#   Downloading gdown-4.5.3-py3-none-any.whl (14 kB)
# Collecting gitdb==4.0.9
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 7.8 MB/s eta 0:00:00
# Collecting gitpython==3.1.29
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 kB 9.3 MB/s eta 0:00:00
# Collecting huggingface-hub==0.10.1
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 18.3 MB/s eta 0:00:00
# Collecting importlib-metadata==5.0.0
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting kneed==0.8.1
#   Downloading kneed-0.8.1-py2.py3-none-any.whl (10 kB)
# Collecting omegaconf==2.2.3
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 8.4 MB/s eta 0:00:00
# Collecting pathtools==0.1.2
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting promise==2.3
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting protobuf==4.21.7
#   Downloading protobuf-4.21.7-cp37-abi3-manylinux2014_x86_64.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.4/408.4 kB 17.8 MB/s eta 0:00:00
# Collecting psutil==5.9.2
#   Downloading psutil-5.9.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.3/281.3 kB 24.4 MB/s eta 0:00:00
# Collecting pyyaml==6.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 31.4 MB/s eta 0:00:00
# Collecting seaborn==0.12.1
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 29.6 MB/s eta 0:00:00
# Collecting sentry-sdk==1.9.10
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 16.3 MB/s eta 0:00:00
# Collecting setproctitle==1.3.2
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting shortuuid==1.0.9
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting smmap==5.0.0
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting timm==0.6.11
#   Downloading timm-0.6.11-py3-none-any.whl (548 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.7/548.7 kB 40.7 MB/s eta 0:00:00
# Collecting torchcam==0.3.2
#   Downloading torchcam-0.3.2-py3-none-any.whl (28 kB)
# Collecting tqdm==4.64.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.7 MB/s eta 0:00:00
# Collecting wandb==0.13.4
#   Downloading wandb-0.13.4-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 50.7 MB/s eta 0:00:00
# Collecting zipp==3.9.0
#   Downloading zipp-3.9.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/envs/egovision/lib/python3.7/site-packages (from docker-pycreds==0.4.0->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/envs/egovision/lib/python3.7/site-packages (from gdown==4.5.3->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 6)) (4.11.1)
# Requirement already satisfied: requests[socks] in /usr/local/envs/egovision/lib/python3.7/site-packages (from gdown==4.5.3->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 6)) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/envs/egovision/lib/python3.7/site-packages (from gitpython==3.1.29->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/envs/egovision/lib/python3.7/site-packages (from huggingface-hub==0.10.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 9)) (21.3)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/envs/egovision/lib/python3.7/site-packages (from kneed==0.8.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 11)) (1.7.3)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from kneed==0.8.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 11)) (1.21.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/envs/egovision/lib/python3.7/site-packages (from seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (3.5.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/envs/egovision/lib/python3.7/site-packages (from seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (1.3.5)
# Requirement already satisfied: certifi in /usr/local/envs/egovision/lib/python3.7/site-packages (from sentry-sdk==1.9.10->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 19)) (2022.9.24)
# Requirement already satisfied: urllib3>=1.26.11 in /usr/local/envs/egovision/lib/python3.7/site-packages (from sentry-sdk==1.9.10->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 19)) (1.26.11)
# Requirement already satisfied: torchvision in /usr/local/envs/egovision/lib/python3.7/site-packages (from timm==0.6.11->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 23)) (0.13.1)
# Requirement already satisfied: torch>=1.7 in /usr/local/envs/egovision/lib/python3.7/site-packages (from timm==0.6.11->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 23)) (1.12.1)
# Requirement already satisfied: Pillow>=8.3.2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from torchcam==0.3.2->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 24)) (9.2.0)
# Requirement already satisfied: setuptools in /usr/local/envs/egovision/lib/python3.7/site-packages (from wandb==0.13.4->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 26)) (63.4.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/envs/egovision/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/envs/egovision/lib/python3.7/site-packages (from pandas>=0.25->seaborn==0.12.1->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 18)) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from requests[socks]->gdown==4.5.3->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/egovision/lib/python3.7/site-packages (from requests[socks]->gdown==4.5.3->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 6)) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/envs/egovision/lib/python3.7/site-packages (from beautifulsoup4->gdown==4.5.3->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/envs/egovision/lib/python3.7/site-packages (from requests[socks]->gdown==4.5.3->-r /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego/condaenv.m4z0pi5_.requirements.txt (line 6)) (1.7.1)
# Building wheels for collected packages: antlr4-python3-runtime, pathtools, promise
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=706d2ca512cf60f4969b5d9383fc820f522bd5f6550fe6b07d21ca8ffe909319
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
#   Building wheel for pathtools (setup.py): started
#   Building wheel for pathtools (setup.py): finished with status 'done'
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8792 sha256=ff56db60d24deecb3727c29a46796492bb4ce3de524256204e9a5291719af5b6
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21486 sha256=70c9e117b965a05ac2329db1ab5f14c3740309de24e89a0f7d88970c0b8f611d
#   Stored in directory: /root/.cache/pip/wheels/29/93/c6/762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
# Successfully built antlr4-python3-runtime pathtools promise
# Installing collected packages: pathtools, antlr4-python3-runtime, zipp, tqdm, smmap, shortuuid, setproctitle, sentry-sdk, pyyaml, psutil, protobuf, promise, filelock, einops, docker-pycreds, omegaconf, kneed, importlib-metadata, gitdb, torchcam, seaborn, huggingface-hub, gitpython, gdown, wandb, timm
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.15.0
#     Uninstalling zipp-3.15.0:
#       Successfully uninstalled zipp-3.15.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.1
#     Uninstalling psutil-5.9.1:
#       Successfully uninstalled psutil-5.9.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
# Successfully installed antlr4-python3-runtime-4.9.3 docker-pycreds-0.4.0 einops-0.5.0 filelock-3.8.0 gdown-4.5.3 gitdb-4.0.9 gitpython-3.1.29 huggingface-hub-0.10.1 importlib-metadata-5.0.0 kneed-0.8.1 omegaconf-2.2.3 pathtools-0.1.2 promise-2.3 protobuf-4.21.7 psutil-5.9.2 pyyaml-6.0 seaborn-0.12.1 sentry-sdk-1.9.10 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 timm-0.6.11 torchcam-0.3.2 tqdm-4.64.1 wandb-0.13.4 zipp-3.9.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate egovision
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# **TIP**: As the creation of the Conda Environment may be a slow process, you may look at the `conda-pack` package to store the environment in a .tar.gz archive you can store on Google Drive and restore later.

# %% [markdown]
# ## Features extraction

# %%
# %%bash
#
# cd /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python
# $PYTHON_PATH save_feat.py name=change_me \
#   config=configs/I3D_save_feat.yaml \
#   dataset.shift=D1-D1 \
#   dataset.RGB.data_path=/content/ek_data/frames
# Out:
# Process is terminated.

# %%
# %%bash
#
# cd /content/drive/MyDrive/MLDL23/mldl23-ego/mldl23-ego
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python3
# $PYTHON_PATH train_classifier.py config=configs/default.yaml
# Out:
# Output hidden; open in https://colab.research.google.com to view.
